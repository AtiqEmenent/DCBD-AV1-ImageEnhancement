# %% [markdown]
# <a href="https://colab.research.google.com/github/AtiqEmenent/DCBD-AV1-ImageEnhancement/blob/main/DCBD_AV1_VideoDenoiser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !nvidia-smi
# Out:
# Wed Apr  1 14:33:18 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd   /content/drive/MyDrive/Github/DCBD-AV1-VideoDenoiser
# Out:
# /content/drive/MyDrive/Github/DCBD-AV1-VideoDenoiser

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Github/DCBD-AV1-VideoDenoiser

# %%
# !python   test_NoSR_AV1_fullImage.py
# Out:
# ===>Testing using weights:  ./checkpoints/model_best.pth
# frame0161_3.png - PSNR: 35.03 dB; SSIM: 0.9576.
# frame0236_3.png - PSNR: 35.59 dB; SSIM: 0.9627.
# frame0253_3.png - PSNR: 35.41 dB; SSIM: 0.9611.
# frame0291_1.png - PSNR: 34.22 dB; SSIM: 0.9337.
# frame0295_1.png - PSNR: 34.08 dB; SSIM: 0.9316.
# frame0356_2.png - PSNR: 34.89 dB; SSIM: 0.9515.
# frame0408_2.png - PSNR: 35.54 dB; SSIM: 0.9575.
# frame0433_2.png - PSNR: 34.76 dB; SSIM: 0.9469.
# frame0474_2.png - PSNR: 34.09 dB; SSIM: 0.9343.
# frame0477_3.png - PSNR: 35.89 dB; SSIM: 0.9657.
# frame0487_3.png - PSNR: 35.87 dB; SSIM: 0.9655.
# frame0638_3.png - PSNR: 35.95 dB; SSIM: 0.9659.
# frame0749_3.png - PSNR: 36.20 dB; SSIM: 0.9679.
# frame0815_3.png - PSNR: 36.17 dB; SSIM: 0.9671.
# frame0961_3.png - PSNR: 36.04 dB; SSIM: 0.9670.
# frame0974_3.png - PSNR: 36.02 dB; SSIM: 0.9662.
# frame1061_3.png - PSNR: 35.84 dB; SSIM: 0.9634.
# Average PSNR/SSIM(RGB) - DCBDNet - PSNR: 35.39 dB; SSIM: 0.9568

# %%
# %%BEFORE TRAINING

# %%
# %%bash
#
#
# ffmpeg -i "Datasets/target/%*.png" \
# -i "Datasets/input/%*.png" \
# -lavfi psnr="stats_file=psnr_log_input.txt" -f null - 2>&1 | \
# grep "average" | tee psnr_summary.txt
# Out:
# [Parsed_psnr_0 @ 0x5734803a2d80] PSNR r:34.766131 g:35.216730 b:34.330576 average:34.756098 min:33.634865 max:35.560184

# %%
# %%AFTER TRAINING

# %%
# %%bash
#
#
# ffmpeg -i  "Datasets/target/%*.png"  \
# -i  "results/Enhanced/%*.png"  \
# -lavfi psnr="stats_file=psnr_log_enhanced.txt" -f null - 2>&1 | \
# grep "average" | tee psnr_summary.txt
# Out:
# [Parsed_psnr_0 @ 0x5d4100e2f340] PSNR r:35.344250 g:35.796701 b:34.855141 average:35.315004 min:34.061679 max:36.188699
